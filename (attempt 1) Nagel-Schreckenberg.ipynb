# %%
import random

# %%
random.random()
# Out:
# 0.6717414426021184

# %%
class car:
    def __init__(x0, v0):
        self.x = x0 # initialise position (x) at initial position (x0)
        self.v = v0 # same for velocity
        
        ## hang on - can maybe simplify. Each position space can only have
        ## one car so position can be used to identify cars

class NS_traffic:
    def __init__(self, M= 1000, N=100, v_max=5, p=1/3):
        self.M = M # number of zones in roadway (positions for cars to be in)
        self.N = N # number of cars
        self.v_max = v_max # speed limit for cars (everyone obeys)
        self.p = p # probability of random slowing
        self.speeds = {} # position:speed
        
        assert M % N == 0, 'Spacing not an integer'
            
        self.initial_spacing = self.M/self.N
        carpos = 0
        
        for car in range(N):
            self.speeds[carpos] = self.v_max
            carpos += self.initial_spacing
        
    def update(self):
        self.newspeeds = {}
        self.newcars = {}
        for car in self.speeds:
            # step 1: try to achieve vmax
            vcar = self.speeds[car]
            if vcar < self.v_max:
                self.newspeeds[car] = vcar + 1
            else:
                self.newspeeds[car] = vcar
                
            # step 2: check distance to car in front
            ## this makes dictionary a bit stupid
            
            δ = 1
            while not (car + δ in self.speeds):
                if car + δ - self.M in self.speeds:
                    # loop distance checking around circular road
                    break
                δ += 1
                print (δ)
                
                # if going to hit car in front, reduce speed
            if self.newspeeds[car] >= δ:
                self.newspeeds[car] = δ - 1
                
            # step 3: randomly slow down with probability p
            
            if random.random() < self.p:
                self.newspeeds[car] = self.newspeeds[car] - 1
                
        # now we have a list of new speeds, but positions have not been updated
                
        for car in self.speeds:

        return δ

# %% [markdown]
# Cars can go backwards!

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
NS1 = NS_traffic()

# %%
NS1.initial_spacing
# Out:
# 10.0

# %% [markdown]
# Note that there is no car at 1000, so there is a distance of 20 units between two of the cars (and 10 between all the rest) ------- no, now its saying they are all 10 which makes more sense

# %%
1000 in NS1.speeds
# Out:
# False

# %%
NS1.update()
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# ...
